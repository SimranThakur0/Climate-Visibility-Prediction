# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler 
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\shiva\\Climate-Visibility-Prediction\\Dataset\\NOAA-JKF-AP.csv')

# %%
#let's scale our data
scale = StandardScaler()

# %%
X = df.drop(['DATE','VISIBILITY'],axis=1)
y = df['VISIBILITY']

# %%
X_scaled = scale.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled,columns=X.columns)

# %%
df.head()
# Out:
#                   DATE  VISIBILITY  DRYBULBTEMPF  WETBULBTEMPF  DewPointTempF  \
# 0  2010-09-18 20:51:00        10.0            64            59             55
# 1  2010-09-18 21:51:00        10.0            63            58             55
# 2  2010-09-18 22:51:00        10.0            63            58             55
# 3  2010-09-18 23:51:00        10.0            63            59             56
# 4  2010-09-19 00:51:00        10.0            63            59             56
#
#    RelativeHumidity  WindSpeed  WindDirection  StationPressure  \
# 0                73          6            160            30.17
# 1                75          3            160            30.17
# 2                75          3            190            30.17
# 3                78          3            210            30.16
# 4                78          5            200            30.16
#
#    SeaLevelPressure  Precip
# 0             30.19     0.0
# 1             30.19     0.0
# 2             30.19     0.0
# 3             30.18     0.0
# 4             30.18     0.0

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
scr = DecisionTreeRegressor()

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid_knn = {"criterion" : ["mse", "friedman_mse", "mae"],
"splitter" : ["best", "random"],
"max_features" :["auto", "sqrt", "log2"],
'max_depth': range(2,16,2),
'min_samples_split': range(2,16,2)    
                 }

# %%
grid =GridSearchCV(scr,param_grid_knn, verbose=3,cv=5)
# finding the best parameters

# %%
grid.fit(X, y)
# Out:
# Fitting 5 folds for each of 882 candidates, totalling 4410 fits
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=auto, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=2, max_features=log2, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=auto, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mse, max_depth=4, max_features=log2, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# ...
# [CV 5/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=sqrt, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=2, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=2, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=4, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=4, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=6, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=6, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=8, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=8, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=10, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=10, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=12, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=12, splitter=random;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=14, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 3/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 4/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# [CV 5/5] END criterion=mae, max_depth=14, max_features=log2, min_samples_split=14, splitter=random;, score=nan total time=   0.0s
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['mse', 'friedman_mse', 'mae'],
#                          'max_depth': range(2, 16, 2),
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_split': range(2, 16, 2),
#                          'splitter': ['best', 'random']},
#              verbose=3)
